# %%
# import library
import seaborn
# canvas (baloon board)
seaborn.set(style='whitegrid')
kashti= seaborn.load_dataset("titanic")
seaborn.boxplot(x= "class", y="fare", data=kashti)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
# import library
import seaborn
import numpy
import matplotlib.pyplot as plt
# canvas (baloon board)
seaborn.set(style='whitegrid')
tip= seaborn.load_dataset("tips")
tip
seaborn.boxplot(x= "day", y="tip", data=tip, saturation=5)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# import library
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# canvas (baloon board)
seaborn.set(style='whitegrid')
tip= seaborn.load_dataset("tips")
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns


# canvas (baloon board)
seaborn.set(style='whitegrid')
tip= sns.load_dataset("tips")
print(tip)
seaborn.boxplot(x =tip['total_bill'])
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <AxesSubplot:xlabel='total_bill'>

# %%
import seaborn as sns


# canvas (baloon board)
sns.set(style='whitegrid')
#tip= sns.load_dataset("tips")
tips = sns.load_dataset("tips")

sns.boxplot(x ="tip", y="day", hue="smoker", data=tips,
            palette="Set2", dodge=True,orient="h")
g=sns.FacetGrid(tips, col="time", row="sex")
g.map(sns.scatterplot, "total_bill", "tip")
g=sns.FacetGrid(tips, col="time", row="sex")
g.map_dataframe(sns.histplot, x="total_bill")
g = sns.FacetGrid(tips, col="time", row="sex")
g.map_dataframe(sns.histplot, x="total_bill", binwidth=2, binrange=(0, 60))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\NASIRN~1\AppData\Local\Temp/ipykernel_8000/3572326555.py in <module>
#       6 #tip= sns.load_dataset("tips")
#       7 tips = sns.load_dataset("tips")
# ----> 8 sns.Facet_wrap(tips)
#       9 sns.boxplot(x ="tip", y="day", hue="smoker", data=tips,
#      10             palette="Set2", dodge=True,orient="h")
#
# AttributeError: module 'seaborn' has no attribute 'Facet_wrap'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
hue_colors = {"YES":"red",
             "NO":"blue"}

# canvas (baloon board)
sns.set(style='whitegrid')
tip= sns.load_dataset("tips")
sns.boxplot(x ="tip", y="day",  data=tip, hue="smoker")
plt.show()

# %%
# import library
import seaborn
# canvas (baloon board)
seaborn.set(style='whitegrid')
kashti= seaborn.load_dataset("titanic")
#seaborn.boxplot(x= "class", y="fare", data=kashti)
sns.boxplot(x="survived",y="age", data=kashti)
plt.show()

# %%
# import library
import seaborn
import matplotlib as plt
import numpy as np
# canvas (baloon board)
#seaborn.set(style='whitegrid')
kashti= seaborn.load_dataset("titanic")
#seaborn.boxplot(x= "class", y="fare", data=kashti)
sns.boxplot(x="survived",y="age", showmeans=True, 
               meanprops={"marker":"+","markersize":"12", "Markeredgecolor":"blue"},data=kashti)
plt.xlabel("Survived number", size=10),
plt.ylabel("Age(years)", size=10),
plt.title("box plot of titanic people",size=14,weight='bold')
plt.show()
#facet wrap and facet grid? assignment
# Out:
# C:\Users\nasirnauman\Anaconda3\lib\site-packages\seaborn\categorical.py:441: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist_dict = ax.boxplot(box_data,
# C:\Users\nasirnauman\Anaconda3\lib\site-packages\seaborn\categorical.py:441: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist_dict = ax.boxplot(box_data,
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NASIRN~1\AppData\Local\Temp/ipykernel_8000/779411919.py in <module>
#       9 sns.boxplot(x="survived",y="age", showmeans=True,
#      10                meanprops={"marker":"+","markersize":"12", "Markeredgecolor":"blue"},data=kashti)
# ---> 11 plt.xlabel("Survived number", size=10),
#      12 plt.ylabel("Age(years)", size=10),
#      13 plt.title("box plot of titanic people",size=14,weight='bold')
#
# TypeError: 'tuple' object is not callable

# %%
import seaborn as sns


# canvas (baloon board)
sns.set(style='whitegrid')
#tip= sns.load_dataset("tips")
tips = sns.load_dataset("tips")
sns.FacetGrid(tips)
g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip", hue="sex")
g.add_legend()
g = sns.FacetGrid(tips, col="day", height=3.5, aspect=.65)
g.map(sns.histplot, "total_bill")

# %%
g = sns.FacetGrid(tips, col="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.refline(y=tips["tip"].median())

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def annotate(data, **kws):
    n = len(data)
    ax = plt.gca()
    ax.text(.1, .6, f"N = {n}", transform=ax.transAxes)

g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.map_dataframe(annotate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NASIRN~1\AppData\Local\Temp/ipykernel_2420/1552862390.py in <module>
#       6     ax.text(.1, .6, f"N = {n}", transform=ax.transAxes)
#       7
# ----> 8 g = sns.FacetGrid(tips, col="time")
#       9 g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
#      10 g.map_dataframe(annotate)
#
# NameError: name 'tips' is not defined

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.set_axis_labels("Total bill ($)", "Tip ($)")
g.set_titles(col_template="{col_name} patrons", row_template="{row_name}")
g.set(xlim=(0, 60), ylim=(0, 12), xticks=[10, 30, 50], yticks=[2, 6, 10])
g.tight_layout()
g.savefig("facet_plot.png")

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True, despine=False)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.figure.subplots_adjust(wspace=0, hspace=0)
for (row_val, col_val), ax in g.axes_dict.items():
    if row_val == "Lunch" and col_val == "Female":
        ax.set_facecolor(".95")
    else:
        ax.set_facecolor((0, 0, 0, 0))
